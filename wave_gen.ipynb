# %%
from matplotlib import pyplot as plt
from wave_definition import sine

# wave = wave_gen.sine_harmonic_3()
wave = [ sum(x) for x in zip(
  sine(),
  sine(A=1/3, freq=3, phase_deg=45), 
  sine(A=1/5, freq=5, phase_deg=90)
)]

plt.plot(wave)
plt.show()
